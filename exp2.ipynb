# %%
#convert celsius to fahrenheit
c=float(input("enter temperature in calsius:"))
f=(c*9/5+32)
print("temperature in fahrenheit = ",f)
# Out:
# enter temperature in calsius:89
# temperature in fahrenheit =  192.2

# %%
#convert km to miles
k=float(input("enter the distance in kilometer:"))
m=round(k*0.62137,2)
print("distance in miles: ",m)
# Out:
# enter the distance in kilometer:59
# distance in miles:  36.66
